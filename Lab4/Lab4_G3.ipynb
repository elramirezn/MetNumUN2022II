# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (x-2)(x-3)(x-5)(x-7)(x-11)(x-12)(x-13)(x-17)(x-19)(x-23) = x^10 - 112 x^9 + 5422 x^8 - 148854 x^7 + 2554920 x^6 - 28490430 x^5 + 207651818 x^4 - 969157346 x^3 + 2747888759 x^2 - 4235969658 x + 2677114440
#
# - (x^10 - 112 x^9 + 5422 x^8 - 148854 x^7 + 2554920 x^6 - 28490430 x^5 + 207651818 x^4 - 969157346 x^3 + 2747888759 x^2 - 4235969658 x + 2677114440) / (x-3) = x^9 - 109 x^8 + 5095 x^7 - 133569 x^6 + 2154213 x^5 - 22027791 x^4 + 141568445 x^3 - 544452011 x^2 + 1114532726 x - 892371480

# %% [markdown]
# ![1.png](data:image/png;base64,...)
# ![2.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')


p = x**10 - 112*x**9 + 5422*x**8 - 148854*x**7 + 2554920*x**6 - 28490430*x**5 + 207651818*x**4 - 969157346*x**3 + 2747888759*x**2 - 4235969658*x + 2677114440
p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)

p, r = div(p,  x-5)

print(p)
print(r)

p, r = div(p,  x-7)

print(p)
print(r)
# Out:
# x**9 - 110*x**8 + 5202*x**7 - 138450*x**6 + 2278020*x**5 - 23934390*x**4 + 159783038*x**3 - 649591270*x**2 + 1448706219*x - 1338557220
# 0
# x**8 - 107*x**7 + 4881*x**6 - 123807*x**5 + 1906599*x**4 - 18214593*x**3 + 105139259*x**2 - 334173493*x + 446185740
# 0
# x**7 - 102*x**6 + 4371*x**5 - 101952*x**4 + 1396839*x**3 - 11230398*x**2 + 48987269*x - 89237148
# 0
# x**6 - 95*x**5 + 3706*x**4 - 76010*x**3 + 864769*x**2 - 5177015*x + 12748164
# 0

# %%
p = x**10 - 112*x**9 + 5422*x**8 - 148854*x**7 + 2554920*x**6 - 28490430*x**5 + 207651818*x**4 - 969157346*x**3 + 2747888759*x**2 - 4235969658*x + 2677114440
p, r = div(p,  x-12)

print(p)
print(r)
# Out:
# x**9 - 100*x**8 + 4222*x**7 - 98190*x**6 + 1376640*x**5 - 11970750*x**4 + 64002818*x**3 - 201123530*x**2 + 334406399*x - 223092870
# 0

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*10 - 112\*x\*\*9 + 5422\*x\*\*8 - 148854\*x\*\*7 + 2554920\*x\*\*6 - 28490430\*x\*\*5 + 207651818\*x\*\*4 - 969157346\*x\*\*3 + 2747888759\*x\*\*2 - 4235969658\*x + 2677114440)

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 112*x**9 + 5422*x**8 - 148854*x**7 + 2554920*x**6 - 28490430*x**5 + 207651818*x**4 - 969157346*x**3 + 2747888759*x**2 - 4235969658*x + 2677114440)
# Out:
# (x - 23)*(x - 19)*(x - 17)*(x - 13)*(x - 12)*(x - 11)*(x - 7)*(x - 5)*(x - 3)*(x - 2)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*10 - 112\*x\*\*9 + 5422\*x\*\*8 - 148854\*x\*\*7 + 2554920\*x\*\*6 - 28490430\*x\*\*5 + 207651818\*x\*\*4 - 969157346\*x\*\*3 + 2747888759\*x\*\*2 - 4235969658\*x + 2677114440 = 0

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 112*x**9 + 5422*x**8 - 148854*x**7 + 2554920*x**6 - 28490430*x**5 + 207651818*x**4 - 969157346*x**3 + 2747888759*x**2 - 4235969658*x + 2677114440, 0), x)
# Out:
# FiniteSet(2, 3, 5, 7, 11, 12, 13, 17, 19, 23)

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi
import math as mt
x = Symbol('x')
e= mt.e
solveset(Eq(2*x**10 *(sqrt(3)+ e) + 12*x**5 *(sqrt(pi)+12) - 3*x**3 *(6*4) , 0), x)
# Out:
# ConditionSet(x, Eq(2*x**10*(sqrt(3) + 2.71828182845905) + 12*x**5*(sqrt(pi) + 12) - 72*x**3, 0), Complexes)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(4*x**10-6*x**7+8*x**4-12*x-24,domain='GF(3)')
# Out:
# -2*x**4*(x - 1)**3*(x + 1)**3

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x*y*z

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  

x = y1 + I*x2
z = z1 + I*x2 
y = x1 + I*y2

print(x*x*y*z*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# (x1 + I*y2)*(I*x2 + y1)**2*(I*x2 + z1)**2
# -x1*x2**2 + I*x1*x2*y1 + I*x1*x2*z1 + x1*y1*z1 - I*x2**2*y2 - x2*y1*y2 - x2*y2*z1 + I*y1*y2*z1
# -x1*x2**2 + I*x1*x2*y1 + I*x1*x2*z1 + x1*y1*z1 - I*x2**2*y2 - x2*y1*y2 - x2*y2*z1 + I*y1*y2*z1
# -x1*x2**2 + I*x1*x2*y1 + I*x1*x2*z1 + x1*y1*z1 - I*x2**2*y2 - x2*y1*y2 - x2*y2*z1 + I*y1*y2*z1
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Cologne in January?
#
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# ![9.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(e**x * sin(2*x), x)
# Out:
# 0.2*2.71828182845905**x*sin(2*x) - 0.4*2.71828182845905**x*cos(2*x)

# %% [markdown]
# ![43.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos
x = Symbol('x')
integrate(e**x * sin(2*x) * cos(3*x), (x,0,12))
# Out:
# 25039.1986798467*cos(24)*cos(36) - 0.153846153846154 + 43818.5976897318*sin(24)*cos(36) - 37558.7980197701*sin(36)*cos(24) + 56338.1970296552*sin(24)*sin(36)

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(e**x * sin(2*x) * cos(3*x), (x,0,12)))
# Out:
# 70118.3776902966
